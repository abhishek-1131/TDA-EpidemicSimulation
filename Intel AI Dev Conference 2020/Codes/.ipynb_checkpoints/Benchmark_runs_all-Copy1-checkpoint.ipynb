# %%
# %%time
import time

from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import matplotlib.pyplot as plt
import umap.umap_ as umap
from sklearn.datasets import make_blobs
import numpy as np
# %matplotlib inline
import scipy
import time
import networkx as nx
import collections
import EoN
from collections import defaultdict
import random
import pandas as pd


sns.set(style='white', context='poster', rc={'figure.figsize':(8,6)})
#default_seed = 16
# Out:
# CPU times: user 3.22 s, sys: 614 ms, total: 3.83 s
# Wall time: 5.42 s

# %%
# %%time
##BASELINE RUN
## 1.25 million, E-I = 0.7, I-R = 0.3, IS-IE = 0.5, IC = 50

start = time.time()
s = 1250000
arr = [int(0.2*s),int(0.05*s),int(0.1*s),int(0.16*s),int(0.12*s),int(0.1*s),int(0.04*s),int(0.08*s),int(0.15*s)]
data,y = make_blobs(n_samples=arr,n_features=2,center_box = (-30,30),random_state=16, cluster_std=1)

time1= time.time()
print("Data creation: ",time1-start)

r = np.random.RandomState(10)

coo_matrix1 = umap.fuzzy_simplicial_set(data,30,r,'euclidean')
coo_matrix1 = np.asarray(coo_matrix1)

time2 = time.time()
print("Fuzzy simplicial:",time2-time1,"   ||| From start: ",time2-start)

#repeat
sparse_matrix = coo_matrix1[0]
#print(sparse_matrix.getnnz())

G1 = nx.from_scipy_sparse_matrix(sparse_matrix)

time3 = time.time()
print("Graph formation:",time3-time2,"   ||| From start: ",time3-start)
#random.seed(0)
#node_attribute_dict = {node: 0.5+random.random() for node in G1.nodes()}
#nx.set_node_attributes(G1, values=node_attribute_dict, name='expose2infect_weight')

H1 = nx.DiGraph()
H1.add_node('S')
H1.add_edge('E', 'I', rate = 0.7)
H1.add_edge('I', 'R', rate = 0.3)

J1 = nx.DiGraph()
J1.add_edge(('I', 'S'), ('I', 'E'), rate = 0.5, weight_label='weight')
IC = defaultdict(lambda: 'S')
for node in range(50):
    IC[node] = 'I'
    
return_statuses = ('S', 'E', 'I', 'R')

t, S, E, I, R = EoN.Gillespie_simple_contagion(G1, H1, J1, IC, return_statuses,
                                        tmax = float('inf'))

plt.semilogy(t, S, label = 'Susceptible')
plt.semilogy(t, E, label = 'Exposed')
plt.semilogy(t, I, label = 'Infected')
plt.semilogy(t, R, label = 'Recovered')
plt.legend()

plt.savefig('results/SEIR_1.25M_baseline.png')
time4 = time.time()
print("SEIR:",time4-time3,"   ||| Total: ",time4-start)
# Out:
# Data creation:  0.5028038024902344
# Fuzzy simplicial: 332.1605246067047    ||| From start:  332.66332840919495
# Graph formation: 332.21887707710266    ||| From start:  664.8822054862976
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/ipykernel_launcher.py:54: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# SEIR: 1097.2235114574432    ||| Total:  1762.1057169437408
# CPU times: user 28min 45s, sys: 1min 3s, total: 29min 49s
# Wall time: 29min 22s
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# %%time
##TRANSMISSION RATE LOCKDOWN RUN
## 1.25 million, E-I = 0.7, I-R = 0.3, IS-IE = 0.3 (lockdown), IC = 50

start = time.time()
s = 1250000
arr = [int(0.2*s),int(0.05*s),int(0.1*s),int(0.16*s),int(0.12*s),int(0.1*s),int(0.04*s),int(0.08*s),int(0.15*s)]
data,y = make_blobs(n_samples=arr,n_features=2,random_state=16, cluster_std=1)

time1= time.time()
print("Data creation: ",time1-start)

r = np.random.RandomState(10)

coo_matrix1 = umap.fuzzy_simplicial_set(data,30,r,'euclidean')
coo_matrix1 = np.asarray(coo_matrix1)

time2 = time.time()
print("Fuzzy simplicial:",time2-time1,"   ||| From start: ",time2-start)

#repeat
sparse_matrix = coo_matrix1[0]
#print(sparse_matrix.getnnz())

G1 = nx.from_scipy_sparse_matrix(sparse_matrix)

time3 = time.time()
print("Graph formation:",time3-time2,"   ||| From start: ",time3-start)
#random.seed(0)
#node_attribute_dict = {node: 0.5+random.random() for node in G1.nodes()}
#nx.set_node_attributes(G1, values=node_attribute_dict, name='expose2infect_weight')

H1 = nx.DiGraph()
H1.add_node('S')
H1.add_edge('E', 'I', rate = 0.7)
H1.add_edge('I', 'R', rate = 0.3)

J1 = nx.DiGraph()
J1.add_edge(('I', 'S'), ('I', 'E'), rate = 0.3, weight_label='weight')
IC = defaultdict(lambda: 'S')
for node in range(50):
    IC[node] = 'I'
    
return_statuses = ('S', 'E', 'I', 'R')

t, S, E, I, R = EoN.Gillespie_simple_contagion(G1, H1, J1, IC, return_statuses,
                                        tmax = float('inf'))

plt.semilogy(t, S, label = 'Susceptible')
plt.semilogy(t, E, label = 'Exposed')
plt.semilogy(t, I, label = 'Infected')
plt.semilogy(t, R, label = 'Recovered')
plt.legend()

plt.savefig('results/SEIR_1.25M_tr30%.png')
time4 = time.time()
print("SEIR:",time4-time3,"   ||| Total: ",time4-start)
# Out:
# Data creation:  0.6287822723388672
# Fuzzy simplicial: 335.7327733039856    ||| From start:  336.36155557632446
# Graph formation: 348.1930515766144    ||| From start:  684.5546071529388
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/ipykernel_launcher.py:51: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# SEIR: 1140.6901438236237    ||| Total:  1825.2447509765625
# CPU times: user 29min 48s, sys: 1min 3s, total: 30min 52s
# Wall time: 30min 25s
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# %%time
##TRANSMISSION RATE NO LOCKDOWN RUN
## 1.25 million, E-I = 0.7, I-R = 0.3, IS-IE = 0.9 (no lockdown), IC = 50

start = time.time()
s = 1250000
arr = [int(0.2*s),int(0.05*s),int(0.1*s),int(0.16*s),int(0.12*s),int(0.1*s),int(0.04*s),int(0.08*s),int(0.15*s)]
data,y = make_blobs(n_samples=arr,n_features=2,random_state=16, cluster_std=1)

time1= time.time()
print("Data creation: ",time1-start)

r = np.random.RandomState(10)

coo_matrix1 = umap.fuzzy_simplicial_set(data,30,r,'euclidean')
coo_matrix1 = np.asarray(coo_matrix1)

time2 = time.time()
print("Fuzzy simplicial:",time2-time1,"   ||| From start: ",time2-start)

#repeat
sparse_matrix = coo_matrix1[0]
#print(sparse_matrix.getnnz())

G1 = nx.from_scipy_sparse_matrix(sparse_matrix)

time3 = time.time()
print("Graph formation:",time3-time2,"   ||| From start: ",time3-start)
#random.seed(0)
#node_attribute_dict = {node: 0.5+random.random() for node in G1.nodes()}
#nx.set_node_attributes(G1, values=node_attribute_dict, name='expose2infect_weight')

H1 = nx.DiGraph()
H1.add_node('S')
H1.add_edge('E', 'I', rate = 0.7)
H1.add_edge('I', 'R', rate = 0.3)

J1 = nx.DiGraph()
J1.add_edge(('I', 'S'), ('I', 'E'), rate = 0.9, weight_label='weight')
IC = defaultdict(lambda: 'S')
for node in range(50):
    IC[node] = 'I'
    
return_statuses = ('S', 'E', 'I', 'R')

t, S, E, I, R = EoN.Gillespie_simple_contagion(G1, H1, J1, IC, return_statuses,
                                        tmax = float('inf'))

plt.semilogy(t, S, label = 'Susceptible')
plt.semilogy(t, E, label = 'Exposed')
plt.semilogy(t, I, label = 'Infected')
plt.semilogy(t, R, label = 'Recovered')
plt.legend()

plt.savefig('results/SEIR_1.25M_tr90%.png')
time4 = time.time()
print("SEIR:",time4-time3,"   ||| Total: ",time4-start)
# Out:
# Data creation:  0.39136219024658203
# Fuzzy simplicial: 415.33172392845154    ||| From start:  415.7230861186981
# Graph formation: 385.814293384552    ||| From start:  801.5373795032501
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/ipykernel_launcher.py:51: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# SEIR: 1100.439024925232    ||| Total:  1901.976404428482
# CPU times: user 30min 53s, sys: 1min 16s, total: 32min 9s
# Wall time: 31min 41s
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# %%time
##INITIAL INFECTED RUN -1 
## 1.25 million, E-I = 0.7, I-R = 0.3, IS-IE = 0.5, IC = 2% (25K)

start = time.time()
s = 1250000
arr = [int(0.2*s),int(0.05*s),int(0.1*s),int(0.16*s),int(0.12*s),int(0.1*s),int(0.04*s),int(0.08*s),int(0.15*s)]
data,y = make_blobs(n_samples=arr,n_features=2,random_state=16, cluster_std=1)

time1= time.time()
print("Data creation: ",time1-start)

r = np.random.RandomState(10)

coo_matrix1 = umap.fuzzy_simplicial_set(data,30,r,'euclidean')
coo_matrix1 = np.asarray(coo_matrix1)

time2 = time.time()
print("Fuzzy simplicial:",time2-time1,"   ||| From start: ",time2-start)

#repeat
sparse_matrix = coo_matrix1[0]
#print(sparse_matrix.getnnz())

G1 = nx.from_scipy_sparse_matrix(sparse_matrix)

time3 = time.time()
print("Graph formation:",time3-time2,"   ||| From start: ",time3-start)
#random.seed(0)
#node_attribute_dict = {node: 0.5+random.random() for node in G1.nodes()}
#nx.set_node_attributes(G1, values=node_attribute_dict, name='expose2infect_weight')

H1 = nx.DiGraph()
H1.add_node('S')
H1.add_edge('E', 'I', rate = 0.7)
H1.add_edge('I', 'R', rate = 0.3)

J1 = nx.DiGraph()
J1.add_edge(('I', 'S'), ('I', 'E'), rate = 0.5, weight_label='weight')
IC = defaultdict(lambda: 'S')
for node in range(int(0.02*s)):
    IC[node] = 'I'
    
return_statuses = ('S', 'E', 'I', 'R')

t, S, E, I, R = EoN.Gillespie_simple_contagion(G1, H1, J1, IC, return_statuses,
                                        tmax = float('inf'))

plt.semilogy(t, S, label = 'Susceptible')
plt.semilogy(t, E, label = 'Exposed')
plt.semilogy(t, I, label = 'Infected')
plt.semilogy(t, R, label = 'Recovered')
plt.legend()

plt.savefig('results/SEIR_1.25M_IC2%.png')
time4 = time.time()
print("SEIR:",time4-time3,"   ||| Total: ",time4-start)
# Out:
# Data creation:  0.3564746379852295
# Fuzzy simplicial: 398.9680759906769    ||| From start:  399.3245506286621
# Graph formation: 380.9565372467041    ||| From start:  780.2810878753662
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/ipykernel_launcher.py:51: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# SEIR: 1158.654662847519    ||| Total:  1938.9357507228851
# CPU times: user 31min 29s, sys: 1min 15s, total: 32min 44s
# Wall time: 32min 18s
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# %%time
##INITIAL INFECTED RUN -2 
## 1.25 million, E-I = 0.7, I-R = 0.3, IS-IE = 0.5, IC = 2% (62.5K)

start = time.time()
s = 1250000
arr = [int(0.2*s),int(0.05*s),int(0.1*s),int(0.16*s),int(0.12*s),int(0.1*s),int(0.04*s),int(0.08*s),int(0.15*s)]
data,y = make_blobs(n_samples=arr,n_features=2,random_state=16, cluster_std=1)

time1= time.time()
print("Data creation: ",time1-start)

r = np.random.RandomState(10)

coo_matrix1 = umap.fuzzy_simplicial_set(data,30,r,'euclidean')
coo_matrix1 = np.asarray(coo_matrix1)

time2 = time.time()
print("Fuzzy simplicial:",time2-time1,"   ||| From start: ",time2-start)

#repeat
sparse_matrix = coo_matrix1[0]
#print(sparse_matrix.getnnz())

G1 = nx.from_scipy_sparse_matrix(sparse_matrix)

time3 = time.time()
print("Graph formation:",time3-time2,"   ||| From start: ",time3-start)
#random.seed(0)
#node_attribute_dict = {node: 0.5+random.random() for node in G1.nodes()}
#nx.set_node_attributes(G1, values=node_attribute_dict, name='expose2infect_weight')

H1 = nx.DiGraph()
H1.add_node('S')
H1.add_edge('E', 'I', rate = 0.7)
H1.add_edge('I', 'R', rate = 0.3)

J1 = nx.DiGraph()
J1.add_edge(('I', 'S'), ('I', 'E'), rate = 0.5, weight_label='weight')
IC = defaultdict(lambda: 'S')
for node in range(int(0.05*s)):
    IC[node] = 'I'
    
return_statuses = ('S', 'E', 'I', 'R')

t, S, E, I, R = EoN.Gillespie_simple_contagion(G1, H1, J1, IC, return_statuses,
                                        tmax = float('inf'))

plt.semilogy(t, S, label = 'Susceptible')
plt.semilogy(t, E, label = 'Exposed')
plt.semilogy(t, I, label = 'Infected')
plt.semilogy(t, R, label = 'Recovered')
plt.legend()

plt.savefig('results/SEIR_1.25M_IC5%.png')
time4 = time.time()
print("SEIR:",time4-time3,"   ||| Total: ",time4-start)
# Out:
# Data creation:  0.37384510040283203
# Fuzzy simplicial: 410.8934609889984    ||| From start:  411.26730608940125
# Graph formation: 383.23564624786377    ||| From start:  794.502952337265
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/ipykernel_launcher.py:51: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# SEIR: 1171.3290131092072    ||| Total:  1965.8319654464722
# CPU times: user 31min 52s, sys: 1min 18s, total: 33min 11s
# Wall time: 32min 45s
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# %%time
##EDGE REMOVAL (threshold = 0.05) 23%
## 1.25 million, E-I = 0.7, I-R = 0.3, IS-IE = 0.5, IC = 50

start = time.time()
s = 1250000
arr = [int(0.2*s),int(0.05*s),int(0.1*s),int(0.16*s),int(0.12*s),int(0.1*s),int(0.04*s),int(0.08*s),int(0.15*s)]
data,y = make_blobs(n_samples=arr,n_features=2,random_state=16, cluster_std=1)

time1= time.time()
print("Data creation: ",time1-start)

r = np.random.RandomState(10)

coo_matrix1 = umap.fuzzy_simplicial_set(data,30,r,'euclidean')
coo_matrix1 = np.asarray(coo_matrix1)

time2 = time.time()
print("Fuzzy simplicial:",time2-time1,"   ||| From start: ",time2-start)

#repeat
sparse_matrix = coo_matrix1[0]
#print(sparse_matrix.getnnz())

G1 = nx.from_scipy_sparse_matrix(sparse_matrix)

time3 = time.time()
print("Graph formation:",time3-time2,"   ||| From start: ",time3-start)
#random.seed(0)
#node_attribute_dict = {node: 0.5+random.random() for node in G1.nodes()}
#nx.set_node_attributes(G1, values=node_attribute_dict, name='expose2infect_weight')
edge_w = nx.get_edge_attributes(G1,'weight')
len(edge_w)
G1.remove_edges_from((e for e, w in edge_w.items() if w < 0.05))
time5 = time.time()
print("Removing edges: ", time5- time3,"   ||| From start: ",time5-start)
edge_w2 = nx.get_edge_attributes(G1,'weight')

print("Removed ",(len(edge_w)-len(edge_w2))*100/len(edge_w), "% edges")



H1 = nx.DiGraph()
H1.add_node('S')
H1.add_edge('E', 'I', rate = 0.7)
H1.add_edge('I', 'R', rate = 0.3)

J1 = nx.DiGraph()
J1.add_edge(('I', 'S'), ('I', 'E'), rate = 0.5, weight_label='weight')
IC = defaultdict(lambda: 'S')
for node in range(50):
    IC[node] = 'I'
    
return_statuses = ('S', 'E', 'I', 'R')

t, S, E, I, R = EoN.Gillespie_simple_contagion(G1, H1, J1, IC, return_statuses,
                                        tmax = float('inf'))

plt.semilogy(t, S, label = 'Susceptible')
plt.semilogy(t, E, label = 'Exposed')
plt.semilogy(t, I, label = 'Infected')
plt.semilogy(t, R, label = 'Recovered')
plt.legend()

plt.savefig('results/SEIR_1.25M_remove_edge#1.png')
time4 = time.time()
print("SEIR:",time4-time5,"   ||| Total: ",time4-start)
# Out:
# Data creation:  0.6352860927581787
# Fuzzy simplicial: 330.9109995365143    ||| From start:  331.54628562927246
# Graph formation: 341.8559920787811    ||| From start:  673.4022777080536
# Removing edges:  90.50919675827026    ||| From start:  763.9114744663239
# Removed  23.23322430520957 % edges
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/ipykernel_launcher.py:61: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# SEIR: 914.9645202159882    ||| Total:  1678.875994682312
# CPU times: user 27min 24s, sys: 1min 1s, total: 28min 25s
# Wall time: 27min 58s
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# %%time
##EDGE REMOVAL (threshold = 0.1) 43%
## 1.25 million, E-I = 0.7, I-R = 0.3, IS-IE = 0.5, IC = 50

start = time.time()
s = 1250000
arr = [int(0.2*s),int(0.05*s),int(0.1*s),int(0.16*s),int(0.12*s),int(0.1*s),int(0.04*s),int(0.08*s),int(0.15*s)]
data,y = make_blobs(n_samples=arr,n_features=2,center_box = (-30,30),random_state=16, cluster_std=1)

time1= time.time()
print("Data creation: ",time1-start)

r = np.random.RandomState(10)

coo_matrix1 = umap.fuzzy_simplicial_set(data,30,r,'euclidean')
coo_matrix1 = np.asarray(coo_matrix1)

time2 = time.time()
print("Fuzzy simplicial:",time2-time1,"   ||| From start: ",time2-start)

#repeat
sparse_matrix = coo_matrix1[0]
#print(sparse_matrix.getnnz())

G1 = nx.from_scipy_sparse_matrix(sparse_matrix)

time3 = time.time()
print("Graph formation:",time3-time2,"   ||| From start: ",time3-start)
#random.seed(0)
#node_attribute_dict = {node: 0.5+random.random() for node in G1.nodes()}
#nx.set_node_attributes(G1, values=node_attribute_dict, name='expose2infect_weight')
edge_w = nx.get_edge_attributes(G1,'weight')
len(edge_w)
G1.remove_edges_from((e for e, w in edge_w.items() if w < 0.1))
time5 = time.time()
print("Removing edges: ", time5- time3,"   ||| From start: ",time5-start)
edge_w2 = nx.get_edge_attributes(G1,'weight')

print("Removed ",(len(edge_w)-len(edge_w2))*100/len(edge_w), "% edges")



H1 = nx.DiGraph()
H1.add_node('S')
H1.add_edge('E', 'I', rate = 0.7)
H1.add_edge('I', 'R', rate = 0.3)

J1 = nx.DiGraph()
J1.add_edge(('I', 'S'), ('I', 'E'), rate = 0.5, weight_label='weight')
IC = defaultdict(lambda: 'S')
for node in range(50):
    IC[node] = 'I'
    
return_statuses = ('S', 'E', 'I', 'R')

t, S, E, I, R = EoN.Gillespie_simple_contagion(G1, H1, J1, IC, return_statuses,
                                        tmax = float('inf'))

plt.semilogy(t, S, label = 'Susceptible')
plt.semilogy(t, E, label = 'Exposed')
plt.semilogy(t, I, label = 'Infected')
plt.semilogy(t, R, label = 'Recovered')
plt.legend()

plt.savefig('results/SEIR_1.25M_remove_edge#2_new.png')
time4 = time.time()
print("SEIR:",time4-time5,"   ||| Total: ",time4-start)
# Out:
# Data creation:  0.36342906951904297
# Fuzzy simplicial: 408.7175967693329    ||| From start:  409.08102583885193
# Graph formation: 368.4440064430237    ||| From start:  777.5250322818756
# Removing edges:  107.72466278076172    ||| From start:  885.2496950626373
# Removed  43.96791576682369 % edges
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/ipykernel_launcher.py:64: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# SEIR: 680.4919745922089    ||| Total:  1565.7416696548462
# CPU times: user 25min 24s, sys: 1min 9s, total: 26min 33s
# Wall time: 26min 5s
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# %%time
##EDGE REMOVAL (threshold = 0.3) 74%
## 1.25 million, E-I = 0.7, I-R = 0.3, IS-IE = 0.5, IC = 50

start = time.time()
s = 1250000
arr = [int(0.2*s),int(0.05*s),int(0.1*s),int(0.16*s),int(0.12*s),int(0.1*s),int(0.04*s),int(0.08*s),int(0.15*s)]
data,y = make_blobs(n_samples=arr,n_features=2,random_state=16, cluster_std=1)

time1= time.time()
print("Data creation: ",time1-start)

r = np.random.RandomState(10)

coo_matrix1 = umap.fuzzy_simplicial_set(data,30,r,'euclidean')
coo_matrix1 = np.asarray(coo_matrix1)

time2 = time.time()
print("Fuzzy simplicial:",time2-time1,"   ||| From start: ",time2-start)

#repeat
sparse_matrix = coo_matrix1[0]
#print(sparse_matrix.getnnz())

G1 = nx.from_scipy_sparse_matrix(sparse_matrix)

time3 = time.time()
print("Graph formation:",time3-time2,"   ||| From start: ",time3-start)
#random.seed(0)
#node_attribute_dict = {node: 0.5+random.random() for node in G1.nodes()}
#nx.set_node_attributes(G1, values=node_attribute_dict, name='expose2infect_weight')
edge_w = nx.get_edge_attributes(G1,'weight')
len(edge_w)
G1.remove_edges_from((e for e, w in edge_w.items() if w < 0.3))
time5 = time.time()
print("Removing edges: ", time5- time3,"   ||| From start: ",time5-start)
edge_w2 = nx.get_edge_attributes(G1,'weight')

print("Removed ",(len(edge_w)-len(edge_w2))*100/len(edge_w), "% edges")



H1 = nx.DiGraph()
H1.add_node('S')
H1.add_edge('E', 'I', rate = 0.7)
H1.add_edge('I', 'R', rate = 0.3)

J1 = nx.DiGraph()
J1.add_edge(('I', 'S'), ('I', 'E'), rate = 0.5, weight_label='weight')
IC = defaultdict(lambda: 'S')
for node in range(50):
    IC[node] = 'I'
    
return_statuses = ('S', 'E', 'I', 'R')

t, S, E, I, R = EoN.Gillespie_simple_contagion(G1, H1, J1, IC, return_statuses,
                                        tmax = float('inf'))

plt.semilogy(t, S, label = 'Susceptible')
plt.semilogy(t, E, label = 'Exposed')
plt.semilogy(t, I, label = 'Infected')
plt.semilogy(t, R, label = 'Recovered')
plt.legend()

plt.savefig('results/SEIR_1.25M_remove_edge#3.png')
time4 = time.time()
print("SEIR:",time4-time5,"   ||| Total: ",time4-start)
# Out:
# Data creation:  0.35913562774658203
# Fuzzy simplicial: 420.9970977306366    ||| From start:  421.3562333583832
# Graph formation: 364.30549335479736    ||| From start:  785.6617267131805
# Removing edges:  143.71433925628662    ||| From start:  929.3760659694672
# Removed  73.90314325003503 % edges
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/ipykernel_launcher.py:61: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# SEIR: 393.60659551620483    ||| Total:  1322.982661485672
# CPU times: user 21min 17s, sys: 1min 11s, total: 22min 28s
# Wall time: 22min 2s
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# %%time
##SUPER-SPREADER REMOVAL 1%
## 1.25 million, E-I = 0.7, I-R = 0.3, IS-IE = 0.5, IC = 50

start = time.time()
s = 1250000
arr = [int(0.2*s),int(0.05*s),int(0.1*s),int(0.16*s),int(0.12*s),int(0.1*s),int(0.04*s),int(0.08*s),int(0.15*s)]
data,y = make_blobs(n_samples=arr,n_features=2,random_state=16, cluster_std=1)

time1= time.time()
print("Data creation: ",time1-start)

r = np.random.RandomState(10)

coo_matrix1 = umap.fuzzy_simplicial_set(data,30,r,'euclidean')
coo_matrix1 = np.asarray(coo_matrix1)

time2 = time.time()
print("Fuzzy simplicial:",time2-time1,"   ||| From start: ",time2-start)

#repeat
sparse_matrix = coo_matrix1[0]
#print(sparse_matrix.getnnz())

G = nx.from_scipy_sparse_matrix(sparse_matrix)

time3 = time.time()
print("Graph formation:",time3-time2,"   ||| From start: ",time3-start)

#########################################################################
print(f'number of edges BEFORE reducing superspreader connections: {G.number_of_edges()}') 
ss = sorted(G.degree, key=lambda x: x[1], reverse=True)
k1=round(1/100 * len(ss))  ## top 1 percent of highest degree nodes
ss1= [i[0] for i in ss]
ss_final = ss1[:k1]

for i in ss_final:
    k2=round(80/100 * len(G.edges(i)))  ## removing random 80% edges/connections of each selected superspreader
    list1 = list(G.edges(i))
    to_remove=random.sample(list1,k2)
    G.remove_edges_from(to_remove)
    
time4 = time.time()
print(f'number of edges AFTER reducing superspreader connections: {G.number_of_edges()}') 
print("reducing superspreader connections (80%):",time4-time3,"   ||| From start: ",time4-start)
#########################################################################

#random.seed(0)
#node_attribute_dict = {node: 0.5+random.random() for node in G1.nodes()}
#nx.set_node_attributes(G1, values=node_attribute_dict, name='expose2infect_weight')

H1 = nx.DiGraph()
H1.add_node('S')
H1.add_edge('E', 'I', rate = 0.7)
H1.add_edge('I', 'R', rate = 0.3)

J1 = nx.DiGraph()
J1.add_edge(('I', 'S'), ('I', 'E'), rate = 0.5, weight_label='weight')
IC = defaultdict(lambda: 'S')
for node in range(50):
    IC[node] = 'I'
    
return_statuses = ('S', 'E', 'I', 'R')

t, S, E, I, R = EoN.Gillespie_simple_contagion(G, H1, J1, IC, return_statuses,
                                        tmax = float('inf'))

plt.semilogy(t, S, label = 'Susceptible')
plt.semilogy(t, E, label = 'Exposed')
plt.semilogy(t, I, label = 'Infected')
plt.semilogy(t, R, label = 'Recovered')
plt.legend()

plt.savefig('ss_1per.png')
time5 = time.time()
print("SEIR:",time5-time4,"   ||| Total: ",time5-start)

# %%
# %%time
##SUPER-SPREADER REMOVAL 2%
## 1.25 million, E-I = 0.7, I-R = 0.3, IS-IE = 0.5, IC = 50

start = time.time()
s = 1250000
arr = [int(0.2*s),int(0.05*s),int(0.1*s),int(0.16*s),int(0.12*s),int(0.1*s),int(0.04*s),int(0.08*s),int(0.15*s)]
data,y = make_blobs(n_samples=arr,n_features=2,random_state=16, cluster_std=1)

time1= time.time()
print("Data creation: ",time1-start)

r = np.random.RandomState(10)

coo_matrix1 = umap.fuzzy_simplicial_set(data,30,r,'euclidean')
coo_matrix1 = np.asarray(coo_matrix1)

time2 = time.time()
print("Fuzzy simplicial:",time2-time1,"   ||| From start: ",time2-start)

#repeat
sparse_matrix = coo_matrix1[0]
#print(sparse_matrix.getnnz())

G = nx.from_scipy_sparse_matrix(sparse_matrix)

time3 = time.time()
print("Graph formation:",time3-time2,"   ||| From start: ",time3-start)

#########################################################################
print(f'number of edges BEFORE reducing superspreader connections: {G.number_of_edges()}') 
ss = sorted(G.degree, key=lambda x: x[1], reverse=True)
k1=round(2/100 * len(ss))  ## top 2 percent of highest degree nodes
ss1= [i[0] for i in ss]
ss_final = ss1[:k1]

for i in ss_final:
    k2=round(80/100 * len(G.edges(i)))  ## removing random 80% edges/connections of each selected superspreader
    list1 = list(G.edges(i))
    to_remove=random.sample(list1,k2)
    G.remove_edges_from(to_remove)
    
time4 = time.time()
print(f'number of edges AFTER reducing superspreader connections: {G.number_of_edges()}') 
print("reducing superspreader connections (80%):",time4-time3,"   ||| From start: ",time4-start)
#########################################################################

#random.seed(0)
#node_attribute_dict = {node: 0.5+random.random() for node in G1.nodes()}
#nx.set_node_attributes(G1, values=node_attribute_dict, name='expose2infect_weight')

H1 = nx.DiGraph()
H1.add_node('S')
H1.add_edge('E', 'I', rate = 0.7)
H1.add_edge('I', 'R', rate = 0.3)

J1 = nx.DiGraph()
J1.add_edge(('I', 'S'), ('I', 'E'), rate = 0.5, weight_label='weight')
IC = defaultdict(lambda: 'S')
for node in range(50):
    IC[node] = 'I'
    
return_statuses = ('S', 'E', 'I', 'R')

t, S, E, I, R = EoN.Gillespie_simple_contagion(G, H1, J1, IC, return_statuses,
                                        tmax = float('inf'))

plt.semilogy(t, S, label = 'Susceptible')
plt.semilogy(t, E, label = 'Exposed')
plt.semilogy(t, I, label = 'Infected')
plt.semilogy(t, R, label = 'Recovered')
plt.legend()

plt.savefig('ss_2per.png')
time5 = time.time()
print("SEIR:",time5-time4,"   ||| Total: ",time5-start)

# %%
# %%time
##SUPER-SPREADER REMOVAL 5%
## 1.25 million, E-I = 0.7, I-R = 0.3, IS-IE = 0.5, IC = 50

start = time.time()
s = 1250000
arr = [int(0.2*s),int(0.05*s),int(0.1*s),int(0.16*s),int(0.12*s),int(0.1*s),int(0.04*s),int(0.08*s),int(0.15*s)]
data,y = make_blobs(n_samples=arr,n_features=2,random_state=16, cluster_std=1)

time1= time.time()
print("Data creation: ",time1-start)

r = np.random.RandomState(10)

coo_matrix1 = umap.fuzzy_simplicial_set(data,30,r,'euclidean')
coo_matrix1 = np.asarray(coo_matrix1)

time2 = time.time()
print("Fuzzy simplicial:",time2-time1,"   ||| From start: ",time2-start)

#repeat
sparse_matrix = coo_matrix1[0]
#print(sparse_matrix.getnnz())

G = nx.from_scipy_sparse_matrix(sparse_matrix)

time3 = time.time()
print("Graph formation:",time3-time2,"   ||| From start: ",time3-start)

#########################################################################
print(f'number of edges BEFORE reducing superspreader connections: {G.number_of_edges()}') 
ss = sorted(G.degree, key=lambda x: x[1], reverse=True)
k1=round(5/100 * len(ss))  ## top 5 percent of highest degree nodes
ss1= [i[0] for i in ss]
ss_final = ss1[:k1]

for i in ss_final:
    k2=round(80/100 * len(G.edges(i)))  ## removing random 80% edges/connections of each selected superspreader
    list1 = list(G.edges(i))
    to_remove=random.sample(list1,k2)
    G.remove_edges_from(to_remove)
    
time4 = time.time()
print(f'number of edges AFTER reducing superspreader connections: {G.number_of_edges()}') 
print("reducing superspreader connections (80%):",time4-time3,"   ||| From start: ",time4-start)
#########################################################################

#random.seed(0)
#node_attribute_dict = {node: 0.5+random.random() for node in G1.nodes()}
#nx.set_node_attributes(G1, values=node_attribute_dict, name='expose2infect_weight')

H1 = nx.DiGraph()
H1.add_node('S')
H1.add_edge('E', 'I', rate = 0.7)
H1.add_edge('I', 'R', rate = 0.3)

J1 = nx.DiGraph()
J1.add_edge(('I', 'S'), ('I', 'E'), rate = 0.5, weight_label='weight')
IC = defaultdict(lambda: 'S')
for node in range(50):
    IC[node] = 'I'
    
return_statuses = ('S', 'E', 'I', 'R')

t, S, E, I, R = EoN.Gillespie_simple_contagion(G, H1, J1, IC, return_statuses,
                                        tmax = float('inf'))

plt.semilogy(t, S, label = 'Susceptible')
plt.semilogy(t, E, label = 'Exposed')
plt.semilogy(t, I, label = 'Infected')
plt.semilogy(t, R, label = 'Recovered')
plt.legend()

plt.savefig('ss_5per.png')
time5 = time.time()
print("SEIR:",time5-time4,"   ||| Total: ",time5-start)
