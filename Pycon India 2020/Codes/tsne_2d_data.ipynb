# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
# %matplotlib inline
import seaborn as sns
import umap.umap_ as umap
import numpy as np
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from mpl_toolkits.mplot3d import Axes3D

# %%
sns.set(style='white', context='poster', rc={'figure.figsize':(10,8)})

# %%
data,y = make_blobs(centers=5, n_samples=1000,n_features=2,random_state=16, cluster_std=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3b4503d1c87b> in <module>
# ----> 1 data,y = make_blobs(centers=5, n_samples=1000,n_features=2,random_state=16, cluster_std=2)
#
# NameError: name 'make_blobs' is not defined

# %%
plt.scatter(data[:,0],data[:,1], c=y)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(data[:,0],data[:,1],data[:,2], c=y)
plt.show()

# %%
from sklearn.decomposition import PCA
X = PCA(n_components = 2).fit_transform(data)
plt.figure(figsize=(20,15))
plt.scatter(X[:, 0], X[:, 1], c = y, s = 50)
plt.title('Principal Component Analysis (PCA)', fontsize = 25)
plt.xlabel("PCA1", fontsize = 22)
plt.ylabel("PCA2", fontsize = 22)
plt.show()

# %%
data.shape
# Out:
# (1000, 2)

# %%
tsne = TSNE()
data_embedded = tsne.fit_transform(data)

# %%
plt.scatter(data_embedded[:,0],data_embedded[:,1], c=y)

# %%
reducer = umap.UMAP()
embedding = reducer.fit_transform(data)

# %%
plt.scatter(embedding[:,0],embedding[:,1], c=y)

# %%
#perplexity - related to number of nearest neighbors
#early_exaggeration - packing/tightness

# %%
tsne = TSNE()
data_embedded = tsne.fit_transform(X)
plt.scatter(data_embedded[:,0],data_embedded[:,1], c=y)

# %%
reducer = umap.UMAP(epochs =100)
embedding = reducer.fit_transform(X)
plt.scatter(embedding[:,0],embedding[:,1], c=y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ef40a145dba9> in <module>
# ----> 1 reducer = umap.UMAP(epochs =100)
#       2 embedding = reducer.fit_transform(X)
#       3 plt.scatter(embedding[:,0],embedding[:,1], c=y)
#
# NameError: name 'umap' is not defined

# %%
y_pred = KMeans(n_clusters=5).fit_predict(X)

# plotting the clusters
plt.scatter(X[:,0],X[:,1], c=y)
plt.title("K-means")
plt.show();
