# %%
# %%time
import time

from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import matplotlib.pyplot as plt
import umap.umap_ as umap
from sklearn.datasets import make_blobs
import numpy as np
# %matplotlib inline
import scipy
import time
import networkx as nx
import collections
from collections import defaultdict
import random
import pandas as pd
import statistics

from seirsplus.models import *
from seirsplus.networks import *
import networkx
sns.set(style='white', context='poster', rc={'figure.figsize':(8,6)})
#default_seed = 16
# Out:
# CPU times: user 3.46 ms, sys: 0 ns, total: 3.46 ms
# Wall time: 3.35 ms

# %% [markdown]
# #### ipfn a and b (for box-plots):

# %%
def ipfnA(s,c_arr, sd, n_neighbors):
    #s= no of points
    #c_arr = Array of centers
    #sd = std. dev.
    #n = n_neighbors 
#     print([s,c_arr, sd, n_neighbors])
    i=n_neighbors
    arr = [int(s/2), int(s/2)]
    data,y = make_blobs(n_samples=arr,n_features=2,random_state=16, centers=c_arr ,cluster_std=sd)
    
    r = np.random.RandomState(10)
    coo_matrix1 = umap.fuzzy_simplicial_set(data,n_neighbors,r,'euclidean')
    coo_matrix1 = np.asarray(coo_matrix1)
    sparse_matrix = coo_matrix1[0]
    #print(sparse_matrix.getnnz()

    return nx.from_scipy_sparse_matrix(sparse_matrix)

# %%
def ipfnAd(s,c_arr, sd, n_neighbors, it):
    #s= no of points
    #c_arr = Array of centers
    #sd = std. dev.
    #n = n_neighbors 
#     print([s,c_arr, sd, n_neighbors])
    i=n_neighbors
    arr = [int(s/2), int(s/2)]
    data,y = make_blobs(n_samples=arr,n_features=2,random_state=16, centers=c_arr ,cluster_std=sd)
    
    r = np.random.RandomState(10)
    coo_matrix1 = umap.fuzzy_simplicial_set(data,n_neighbors,r,'euclidean')
    coo_matrix1 = np.asarray(coo_matrix1)
    sparse_matrix = coo_matrix1[0]
    #print(sparse_matrix.getnnz()
    plt.figure(it)
    #plt.scatter(data[:,0],data[:,1], c=y, cmap = 'viridis')
    nx.draw( nx.from_scipy_sparse_matrix(sparse_matrix), pos =  data)

    return nx.from_scipy_sparse_matrix(sparse_matrix)

# %%
def ipfnB(G1,s=1000):
#s = no of points
    SIGMA  = 1/5.2
    GAMMA  = 1/10
    MU_I   = 0.002

    R0     = 2.5
    BETA   = 1/(1/GAMMA) * R0
    BETA_Q = 0.5*BETA

    P      = 0.2
    Q      = 0.05
    
    model_base = SEIRSNetworkModel(G       = G1, 
                          beta    = BETA, 
                          sigma   = SIGMA, 
                          gamma   = GAMMA, 
                          initE = s*0.4, initI = s*0.1)
    
    model_base.run(T=300)
    fig,axs = model_base.figure_basic(ylim=0.5,xlim=100)
    
    line = axs.lines[1]
    p = line.get_data()
    p0 = p[0].compressed()
    p1 = p[1].compressed()
    #Maximum
    m = max(p[1])
    #Days Max
    ind= numpy.argmax(p[1])
    d = p[0][numpy.argmax(p[1])]
    #Mean and St Deviation
    mean  = statistics.mean(p1)
    stdev =  statistics.stdev(p1)
    line1 = axs.lines[2]
    w = line1.get_data()
    #Total Infections
    tot = 1 -(w[1][w[1].shape[0]-1])
    tp = 0.1*m
    np = 0.9*m
    #Ten Percent
    tpl =[]
    for i in range(len(p1)):
        x = numpy.abs(p1[i]-tp)
        if(x<0.001):
            #print(p1[i],x,p0[i])
            tpl.append(p0[i])
    tplval = statistics.mean(tpl)
    
    #Ninety Percent
    nplfh =[]
    nplsh = []
    for i in range(ind):
        x = numpy.abs(p1[i]-np)
        if(x<0.001):
            #print(p1[i],x,p0[i])
            nplfh.append(p0[i])
    for i in range(ind, len(p1)):
        x = numpy.abs(p1[i]-np)
        if(x<0.001):
            #print(p1[i],x,p0[i])
            nplsh.append(p0[i])
    npl=[(statistics.mean(nplfh)),(statistics.mean(nplsh))]
    
    
    return m,d,tot,tplval,npl, mean, stdev

# %%
import statistics as st

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
graph_list = []
for l in range(6):
    for sdv in range(1, 7):
        graph = ipfnA(1000,[[1,1],[1,10*l]],(5*sdv +0.5),30)
        graph_list.append(graph)

# %%
cent = [0,2,4,6]
sd = [0,1,2,3]

# %%
graph_list = []

i=0
for l in cent:
    for sdv in cent:
        graph = ipfnAd(1000,[[1,0],[1,10*l]],(sdv +0.5),30,i)
        graph_list.append(graph)
        i = i+1

# %%
graph_list

# %%
for i in graph_list:
    nx.draw(i)

# %%
y,x,t,tp,npl,avg,stdv = ipfnB(graph_list[0])
# Out:
# t = 0.01
# t = 10.01
# t = 20.03
# t = 30.08
# t = 40.40
# t = 50.02
# t = 60.66
# t = 70.06
# t = 90.47
# 0.032 0.0003999999999999976 51.815221001738976
# 0.031 0.0006000000000000033 51.82287650978141
# 0.031 0.0006000000000000033 51.84421930785666
# 0.031 0.0006000000000000033 52.112523938139454
# 0.031 0.0006000000000000033 52.282893311199345
# 0.284 0.00040000000000001146 4.721846828882778
# 0.284 0.00040000000000001146 4.929727572822447
# 0.284 0.00040000000000001146 4.943135258654087
# 0.284 0.00040000000000001146 4.974220067543236
# 0.284 0.00040000000000001146 4.990508844326118
# 0.284 0.00040000000000001146 5.037769626894519
# 0.285 0.0005999999999999894 5.038131644120001
# 0.285 0.0005999999999999894 5.173303447372681
# 0.285 0.0005999999999999894 5.233017144239542
# 0.285 0.0005999999999999894 5.238212669741578
# 0.285 0.0005999999999999894 5.439987347567262
# 0.285 0.0005999999999999894 5.46445236118229
# 0.285 0.0005999999999999894 12.051737124057626
# ...

# %%
print(y,x,t,tp,npl,avg,stdv)
# Out:
# 0.316 7.682270249172035 0.806 51.97554681374317 [5.098692734445545, 12.213176366358576] 0.20969345074298293 0.08344886934638084

# %%
Y = []
X = []
T= []
TP=[]
NP=[]
Avg=[]
Stdev= []
for i in graph_list:
    for _ in range(1):
        y,x,t,tp,npl,avg,stdv = ipfnB(i)
        Y.append(y)
        X.append(x)
        T.append(t)
        TP.append(tp)
        NP.append(npl)
        Avg.append(avg)
        Stdev.append(stdv)
# Out:
# t = 0.00
# t = 10.01
# t = 20.07
# t = 30.04
# t = 40.10
# t = 50.04
# t = 60.08
# t = 0.01
# t = 10.00
# t = 20.03
# t = 30.06
# t = 40.26
# t = 50.86
# t = 60.01
# t = 90.35
# t = 110.13
# t = 0.01
# t = 10.02
# t = 20.05
# t = 30.07
# t = 40.02
# t = 50.05
# t = 60.44
# t = 70.81
# t = 0.01
# t = 10.00
# t = 20.06
# t = 30.06
# t = 40.00
# t = 50.17
# t = 60.78
# t = 70.78
# t = 0.01
# t = 10.02
# t = 20.04
# t = 30.19
# t = 40.06
# t = 50.07
# t = 60.31
# t = 0.01
# t = 10.02
# t = 20.04
# t = 30.01
# t = 40.09
# t = 50.14
# t = 60.07
# t = 70.79
# t = 80.44
# t = 90.60
# t = 0.00
# t = 10.03
# t = 20.02
# t = 30.03
# t = 40.13
# t = 50.23
# t = 60.40
# t = 0.02
# t = 10.00
# t = 20.01
# t = 30.03
# t = 40.21
# t = 50.02
# t = 60.87
# t = 70.46
# t = 90.34
# t = 0.02
# t = 10.04
# t = 20.01
# t = 30.00
# t = 40.01
# t = 50.75
# t = 60.02
# t = 70.60
# t = 80.01
# t = 100.11
# t = 0.01
# t = 10.00
# t = 20.06
# t = 30.01
# t = 40.01
# t = 50.62
# t = 60.12
# t = 70.65
# t = 0.01
# ...

# %%
len(graph_list)
# Out:
# 16

# %%
for i in range(16):
    print(Y[i],X[i],T[i],TP[i],NP[i],Avg[i],Stdev[i])
# Out:
# 0.271 8.821480669545215 0.794 48.51335102525595 [5.315718183760066, 15.808739730171482] 0.1974837261503928 0.06823864483638523
# 0.277 5.578955166896077 0.764 46.23695887833566 [3.4166013513116913, 12.080124686450839] 0.18696040189125296 0.07997474596564157
# 0.284 8.050608263901019 0.784 48.43040410573917 [5.715926098042227, 12.452763705429197] 0.19757338663620788 0.07346383491144177
# 0.277 8.672201410010487 0.795 50.96728364643862 [4.558620709904145, 11.225609923319249] 0.19252885154061625 0.0699007815579589
# 0.294 5.633353554943209 0.779 49.32724647419841 [3.747272191984245, 8.981601170985886] 0.19948819804260218 0.07585880806078588
# 0.278 9.734793224221722 0.7969999999999999 50.39923967356296 [6.488453841967531, 14.549445739741696] 0.1900106085985483 0.07186840394192798
# 0.296 6.401068296130537 0.792 54.711936611518965 [4.289380375279581, 10.673711983719672] 0.2000382882882883 0.07834930596022324
# ...

# %%
y,x = ipfnB(graph_list[5])
# Out:
# t = 0.02
# t = 10.01
# t = 20.04
# t = 30.03
# t = 40.08
# t = 50.08
# t = 60.64
# t = 70.31
# t = 80.58
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-1d385f215087> in <module>
# ----> 1 y,x = ipfnB(graph_list[5])
#
# ValueError: too many values to unpack (expected 2)

# %%
y,x = ipfnB(graph_list[31])
# Out:
# t = 0.04
# t = 10.00
# t = 20.01
# t = 30.00
# t = 40.03
# t = 50.40
# t = 60.14
# t = 70.69
# t = 100.81
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-83dc64f50450> in <module>
# ----> 1 y,x = ipfnB(graph_list[31])
#
# ValueError: too many values to unpack (expected 2)

# %%
import pickle

# %%
data = [Y,X,T]
with open('data.pkl', 'wb') as outfile:
    pickle.dump(data, outfile, pickle.HIGHEST_PROTOCOL)

# %%
with open('data.pkl', 'rb') as infile:
    result = pickle.load(infile)

# %%
Y1 = result[0]
X1 = result[1]
T1 = result[2]
Y1 = np.asarray(Y1)
X1 = np.asarray(X1)
T1 = np.asarray(T1)

# %%
Y1 = np.split(Y1,36)
X1 = np.split(X1,36)
T1 = np.split(T1,36)

# %%
#first sub-list in Y1 = box-plot values (10 iterations) for plot@[1,1] in (6x6) grid
#second sub-list in Y1 = box-plot values (10 iterations) for plot@[1,2] in (6x6) grid
#first six sub lists in Y1 = box-plot values for 1st row in (6x6) grid

# %%
Y1 = np.asarray(Y1)
Y1bp = np.split(Y1,6)

# %%
Y1bp = np.asarray(Y1bp)
Y1bp.shape
# Out:
# (6, 6, 20)

# %%
Y01 = Y1bp[0].transpose()
Y02 = Y1bp[1].transpose()
Y03 = Y1bp[2].transpose()
Y04 = Y1bp[3].transpose()
Y05 = Y1bp[4].transpose()
Y06 = Y1bp[5].transpose()

# %%
fig, axm = plt.subplots(2,1, figsize= (10,12), sharex =True,sharey =True)
axm[0].boxplot(Y01)
axm[1].boxplot(Y02)
fig, axm = plt.subplots(2,1, figsize= (10,12), sharex =True,sharey =True)
axm[0].boxplot(Y03)
axm[1].boxplot(Y04)
fig, axm = plt.subplots(2,1, figsize= (10,12), sharex =True,sharey =True)
axm[0].boxplot(Y05)
axm[1].boxplot(Y06)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f055da3e610>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f055da44150>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f055da44190>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f055da44250>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f05d7e09d50>,
# ...
#  'means': []}

# %%
X1 = np.asarray(X1)
X1bp = np.split(X1,6)
X1bp = np.asarray(X1bp)
X1bp.shape
# Out:
# (6, 6, 20)

# %%
X01 = X1bp[0].transpose()
X02 = X1bp[1].transpose()
X03 = X1bp[2].transpose()
X04 = X1bp[3].transpose()
X05 = X1bp[4].transpose()
X06 = X1bp[5].transpose()

# %%
fig, axm = plt.subplots(2,1, figsize= (10,12), sharex =True,sharey =True)
axm[0].boxplot(X01)
axm[1].boxplot(X02)
fig, axm = plt.subplots(2,1, figsize= (10,12), sharex =True,sharey =True)
axm[0].boxplot(X03)
axm[1].boxplot(X04)
fig, axm = plt.subplots(2,1, figsize= (10,12), sharex =True,sharey =True)
axm[0].boxplot(X05)
axm[1].boxplot(X06)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f055d455610>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f055d3cdd10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f055d455650>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f055d3d5790>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f055d3d5c90>,
# ...
#  'means': []}

# %%
T1 = np.asarray(T1)
T1bp = np.split(T1,6)
T1bp = np.asarray(T1bp)
T1bp.shape
# Out:
# (6, 6, 20)

# %%
T01 = T1bp[0].transpose()
T02 = T1bp[1].transpose()
T03 = T1bp[2].transpose()
T04 = T1bp[3].transpose()
T05 = T1bp[4].transpose()
T06 = T1bp[5].transpose()

# %%
fig, axm = plt.subplots(2,1, figsize= (10,12), sharex =True,sharey =True)
axm[0].boxplot(T01)
axm[1].boxplot(T02)
fig, axm = plt.subplots(2,1, figsize= (10,12), sharex =True,sharey =True)
axm[0].boxplot(T03)
axm[1].boxplot(T04)
fig, axm = plt.subplots(2,1, figsize= (10,12), sharex =True,sharey =True)
axm[0].boxplot(T05)
axm[1].boxplot(T06)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f055cd9ef90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f055cda99d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f055ceb1310>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f055ceb12d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f055cdb3950>,
# ...
#  'means': []}
