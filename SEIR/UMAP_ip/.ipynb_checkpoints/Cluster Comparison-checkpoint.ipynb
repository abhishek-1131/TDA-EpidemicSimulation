# %%
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import matplotlib.pyplot as plt
import umap.umap_ as umap
from sklearn.datasets import make_blobs
import numpy as np
# %matplotlib inline
import scipy
import time
import networkx as nx
import collections
from collections import defaultdict
import random
import pandas as pd
import statistics

from models_updated import *
import networkx as nx

import random

sns.set(style='white', context='poster', rc={'figure.figsize':(8,6)})
#default_seed = 16

# %%
def ipfnA(data, n_neighbors):
    #s= no of points
    #c_arr = Array of centers
    #sd = std. dev.
    #n = n_neighbors 
#     print([s,c_arr, sd, n_neighbors])

    
    r = np.random.RandomState(10)
    coo_matrix1 = umap.fuzzy_simplicial_set(data,n_neighbors,r,'euclidean')
    coo_matrix1 = np.asarray(coo_matrix1)
    sparse_matrix = coo_matrix1[0]
    #print(sparse_matrix.getnnz()

    return nx.from_scipy_sparse_matrix(sparse_matrix)

# %%
import pickle
with open('Cluster Experiments/cluster1.pkl', 'rb') as infile:
    data1 = pickle.load(infile)
    
with open('Cluster Experiments/cluster2.pkl', 'rb') as infile:
    data2 = pickle.load(infile)

# %% [markdown]
# Clusters:
#     Cluster 1: Centre (1,1)
#         Cluster 2: Centre (1,21)
#             Standard Deviation for both is #3

# %%
def ipfnB(G1,s):
#s = no of points
    SIGMA  = 1/5.2
    GAMMA  = 1/10
    MU_I   = 0.002

    R0     = 2.5
    BETA   = 1/(1/GAMMA) * R0
    BETA_Q = 0.5*BETA

    P      = 0.2
    Q      = 0.05
    
    model_base = SEIRSNetworkModel(G       = G1, 
                          beta    = BETA, 
                          sigma   = SIGMA, 
                          gamma   = GAMMA, 
                          initE = s*0.30, initI = s*0.1)
    
    model_base.run(T=300)
    fig,axs = model_base.figure_basic(ylim=0.75,xlim=100)
    
    line = axs.lines[1]
    p = line.get_data()
    p0 = p[0].compressed()
    p1 = p[1].compressed()
    #Maximum
    m = max(p[1])
    #Days Max
    ind= numpy.argmax(p[1])
    d = p[0][numpy.argmax(p[1])]
    #Mean and St Deviation
    mean  = statistics.mean(p1)
    stdev =  statistics.stdev(p1)
    line1 = axs.lines[2]
    w = line1.get_data()
    #Total Infections
    tot = 1 -(w[1][w[1].shape[0]-1])
    tp = 0.1*m
    np = 0.9*m
    #Ten Percent
    tpl =[]
    for i in range(len(p1)):
        x = numpy.abs(p1[i]-tp)
        if(x<0.001):
            #print(p1[i],x,p0[i])
            tpl.append(p0[i])
    tplval = statistics.mean(tpl)
    
    #Ninety Percent
    nplfh =[]
    nplsh = []
    for i in range(ind):
        x = numpy.abs(p1[i]-np)
        if(x<0.001):
            #print(p1[i],x,p0[i])
            nplfh.append(p0[i])
    for i in range(ind, len(p1)):
        x = numpy.abs(p1[i]-np)
        if(x<0.001):
            #print(p1[i],x,p0[i])
            nplsh.append(p0[i])
    npl=[(statistics.mean(nplfh)),(statistics.mean(nplsh))]
    
    P = model_base.X
    cluster2 = P[1000:]
    count =0
    for i in cluster2:
        if(i==4):
            count = count+1
            
    lday = p0[(len(p0)-1)]
    
    
    return m,d,tot,tplval,npl, mean, stdev,count,lday

# %%
graph1 = ipfnA(data1,20)
# Out:
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
graph2 = ipfnA(data2,20)

# %%
d3 =[]
for i in data1:
    d3.append(i)
for k in data2:
    d3.append(k)
d3 = np.asarray(d3)

# %%
import pickle
data = d3
with open('Cluster Experiments/Full_data_loc.pkl', 'wb') as outfile:
    pickle.dump(data, outfile, pickle.HIGHEST_PROTOCOL)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e9464fd8311e> in <module>
#       1 import pickle
# ----> 2 data = d3
#       3 with open('Cluster Experiments/Full_data_loc.pkl', 'wb') as outfile:
#       4     pickle.dump(data, outfile, pickle.HIGHEST_PROTOCOL)
#
# NameError: name 'd3' is not defined

# %%
graph_base = nx.disjoint_union(graph1,graph2)

# %%
graph_list =[]

# %%
graph_list.append(graph_base)

# %%
nx.draw(graph_list[0],pos=d3,node_size =10)

# %%
def add_edges(n):
    edges = n
    edge_list=[]
    for i in range(edges):
        x= random.randint(0,999)
        y= random.randint(1000,1999)
        edge_list.append((x,y))

    graph_temp = nx.disjoint_union(graph1,graph2)
    graph_temp.add_edges_from(edge_list)

    graph_list.append(graph_temp)

# %%
nedges =[]
for x in range(1,11):
    nedges.append(100*x)

# %%
nedges
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]

# %%
for n in nedges:
    add_edges(n)

# %%
len(graph_list)
# Out:
# 11

# %%
def removeDuplicates(lst): 
      
    return list(set([i for i in lst]))

# %%
edge_list = removeDuplicates(edge_list)

# %%
len(edge_list)
# Out:
# 10944

# %%
graph_temp = nx.disjoint_union(graph1,graph2)
graph_temp.add_edges_from(edge_list)

graph_list.append(graph_temp)

# %%
with open('Cluster Experiments/graph_list_long.pkl', 'wb') as outfile:
    pickle.dump(graph_list, outfile, pickle.HIGHEST_PROTOCOL)

# %%
with open('Cluster Experiments/graph_list_long.pkl', 'rb') as infile:
    graph_list_add = pickle.load(infile)

# %%
Y=[]
X=[]
T=[]
TP=[]
NPL=[]
AVG=[]
STDV=[]
COUNT =[]
LDAY =[]

# %%
for graph in graph_list:
    y,x,t,tp,npl,avg,stdv,count,lday = ipfnB(graph,2000)
    Y.append(y)
    X.append(x)
    T.append(t)
    TP.append(tp)
    NPL.append(npl)
    AVG.append(avg)
    STDV.append(stdv)
    COUNT.append(count)
    LDAY.append(lday)
# Out:
# t = 0.00
# t = 10.00
# t = 20.13
# t = 30.10
# t = 40.18
# t = 50.17
# t = 60.34
# t = 0.00
# t = 10.04
# t = 20.02
# t = 30.03
# t = 40.24
# t = 50.01
# t = 60.49
# t = 70.32
# t = 80.12
# t = 90.26
# t = 0.00
# t = 10.01
# t = 20.01
# t = 30.00
# t = 40.01
# t = 50.11
# t = 60.06
# t = 70.41
# t = 80.79
# t = 90.30
# t = 100.32
# t = 120.69
# t = 0.00
# t = 10.05
# t = 20.04
# t = 30.05
# t = 40.00
# t = 50.01
# t = 60.03
# t = 70.46
# t = 80.19
# t = 90.81
# t = 100.07
# t = 110.75
# t = 130.99
# t = 0.00
# t = 10.02
# t = 20.01
# t = 30.16
# t = 40.05
# t = 50.05
# t = 60.37
# t = 70.03
# t = 80.03
# t = 90.40
# t = 100.84
# t = 110.46
# t = 130.31
# t = 0.01
# t = 10.02
# t = 20.02
# t = 30.03
# t = 40.01
# t = 50.18
# t = 60.07
# t = 70.02
# t = 80.14
# t = 90.45
# t = 100.87
# t = 110.11
# t = 120.11
# t = 130.33
# t = 0.01
# t = 10.00
# t = 20.01
# t = 30.01
# t = 40.03
# t = 50.02
# t = 60.29
# t = 70.11
# t = 80.08
# t = 90.30
# t = 100.05
# t = 110.38
# t = 140.18
# t = 0.01
# t = 10.01
# t = 20.01
# t = 30.04
# t = 40.00
# t = 50.03
# t = 60.29
# t = 70.06
# t = 80.02
# t = 90.57
# t = 100.55
# t = 0.01
# t = 10.01
# t = 20.03
# t = 30.01
# t = 40.01
# t = 50.00
# t = 60.11
# t = 70.06
# t = 80.91
# t = 90.24
# t = 100.33
# t = 110.35
# t = 120.56
# t = 140.20
# t = 0.02
# t = 10.01
# t = 20.01
# t = 30.01
# t = 40.09
# t = 50.11
# t = 60.33
# t = 70.48
# t = 80.34
# t = 100.17
# t = 0.01
# t = 10.02
# t = 20.03
# t = 30.01
# t = 40.05
# t = 50.02
# t = 60.12
# t = 70.03
# t = 80.03
# t = 90.00
# t = 130.56

# %%
len(Y)
# Out:
# 0

# %%
with open('Cluster Experiments/Edge_tests.pkl', 'rb') as infile:
    op = pickle.load(infile)

# %%
with open('Cluster Experiments/Edge_tests.pkl', 'wb') as outfile:
    pickle.dump([Y,X,T,TP,NPL,AVG,STDV,COUNT], outfile, pickle.HIGHEST_PROTOCOL)

# %%
import pandas as pd

# %%
# Out:
# [0.224,
#  0.2345,
#  0.2275,
#  0.2265,
#  0.2365,
#  0.2495,
#  0.2505,
#  0.2435,
#  0.254,
#  0.2625,
#  0.2865,
#  0.2615,
#  0.275,
#  0.2785,
#  0.28,
#  0.3025,
#  0.2875,
#  0.27,
#  0.287,
#  0.2835,
#  0.286]

# %%
df = pd.DataFrame()
df['Y']= Y + op[0][2:]
df['X'] = X +op[1][2:]
df['T'] = T+op[2][2:]
df['Total'] = total
df['Cluster1_Inf'] = cluster1_inf
df['Clustr2_Inf'] = COUNT+op[7][2:]
df['Standard Deviation'] = STDV+op[6][2:]
#df['NPL']=NPL+op[4][1:]
df['rows'] = mycols

# %%
mycols = ['0','100','200','300','400','500','600','700','800','900','1k','1.5k','2k','2.5k','3k','3.5k','4','4.5k','5k','5.5k','6k','6.5k','7k','7.5k','8k','8.5k','9k','9.5k','10k','10.5k','11k']
#df= df.transpose()

# %%
df.columns = mycols

# %%
df = df.transpose()

# %%
df
# Out:
#          Y          X       T   Total  Cluster1_Inf  Clustr2_Inf  \
# 0   0.2170   4.846378  0.4745   949.0         949.0            0
# 1   0.2205   7.183964  0.4970   994.0         934.0           60
# 2   0.2235   5.937872  0.5410  1082.0         934.0          148
# 3   0.2240   6.470207  0.5915  1183.0         930.0          253
# 4   0.2280   6.097366  0.5985  1197.0         938.0          259
# 5   0.2215   5.946489  0.6500  1300.0         944.0          356
# 6   0.2190   7.222292  0.6445  1289.0         939.0          350
# 7   0.2085   5.674418  0.6555  1311.0         941.0          370
# 8   0.2185   5.648869  0.6950  1390.0         952.0          438
# 9   0.2240   9.928668  0.6645  1329.0         932.0          397
# 10  0.2245   6.325846  0.7270  1454.0         944.0          510
# 11  0.2345   7.622610  0.7465  1493.0         931.0          562
# 12  0.2275   8.316415  0.7585  1517.0         935.0          582
# 13  0.2265   8.700803  0.8185  1637.0         952.0          685
# 14  0.2365   8.029598  0.8055  1611.0         936.0          675
# 15  0.2495   6.209698  0.8290  1658.0         951.0          707
# 16  0.2505   6.107232  0.8260  1652.0         941.0          711
# 17  0.2435   8.898156  0.8385  1677.0         950.0          727
# 18  0.2540   9.869915  0.8500  1700.0         946.0          754
# 19  0.2625   9.507120  0.8595  1719.0         965.0          754
# 20  0.2865  10.602165  0.8765  1753.0         961.0          792
# 21  0.2615  12.234556  0.8745  1749.0         965.0          784
# 22  0.2750   9.038034  0.8595  1719.0         947.0          772
# 23  0.2785   9.599648  0.8720  1744.0         962.0          782
# 24  0.2800  11.468816  0.8755  1751.0         960.0          791
# 25  0.3025  10.287219  0.8955  1791.0         956.0          835
# 26  0.2875   9.506212  0.8925  1785.0         954.0          831
# 27  0.2700  10.217099  0.8910  1782.0         961.0          821
# 28  0.2870  10.250663  0.8965  1793.0         966.0          827
# 29  0.2835  12.500731  0.9055  1811.0         970.0          841
# 30  0.2860  10.377500  0.8975  1795.0         966.0          829
#
#     Standard Deviation   rows
# 0             0.054319      0
# 1             0.060242    100
# 2             0.069301    200
# 3             0.070713    300
# 4             0.071236    400
# 5             0.068548    500
# 6             0.065674    600
# 7             0.060056    700
# 8             0.064709    800
# 9             0.065370    900
# 10            0.064627     1k
# 11            0.064017   1.5k
# 12            0.060605     2k
# 13            0.061633   2.5k
# 14            0.059887     3k
# 15            0.065499   3.5k
# 16            0.064332      4
# 17            0.061115   4.5k
# 18            0.065163     5k
# 19            0.068289   5.5k
# 20            0.072320     6k
# 21            0.065830   6.5k
# 22            0.067830     7k
# 23            0.069512   7.5k
# 24            0.073744     8k
# 25            0.074433   8.5k
# 26            0.073054     9k
# 27            0.068659   9.5k
# 28            0.072637    10k
# 29            0.070360  10.5k
# 30            0.070999    11k

# %%
df1 = df.iloc[:7,:]
df2= df.iloc[7:,:]

# %%
ax = plt.gca()

df.plot(kind='line',x='rows',y='Total',ax=ax)
df.plot(kind='line',x='rows',y='Cluster1_Inf',ax=ax)
df.plot(kind='line',x='rows',y='Clustr2_Inf',ax=ax)

plt.show()

# %%
df.plot('rows','Y')
plt.ylim([0,0.30])
# Out:
# (0, 0.3)

# %%
df.plot('rows','Standard Deviation')

# %%
df.plot('rows','X')

# %%
total = np.asarray(T+op[2][2:] )
counts = np.asarray(COUNT+op[7][2:])
cluster1_inf = (total*2000)-counts
total = total*2000

# %%
count_m=[]
for graph in graph_list:
    SIGMA  = 1/5.2
    GAMMA  = 1/10
    s=2000
    R0     = 2.5
    BETA   = 1/(1/GAMMA) * R0
    model_base = SEIRSNetworkModel(G       = graph, 
                          beta    = BETA, 
                          sigma   = SIGMA, 
                          gamma   = GAMMA, 
                          initE = s*0.30, initI = s*0.1)
    model_base.run(T=300)
    fig,axs = model_base.figure_basic(ylim=0.75,xlim=100)
    P = model_base.X
    cluster2 = P[1000:]
    count =0
    for i in cluster2:
        if(i==4):
            count = count+1
    count_m.append(count)
# Out:
# t = 0.00
# t = 10.00
# t = 20.01
# t = 30.11
# t = 40.01
# t = 50.02
# t = 60.45
# t = 70.08
# t = 0.01
# t = 10.01
# t = 20.03
# t = 30.34
# t = 40.09
# t = 50.29
# t = 60.31
# t = 70.05
# t = 90.38
# t = 100.20
# t = 0.02
# t = 10.02
# t = 20.01
# t = 30.03
# t = 40.26
# t = 50.01
# t = 60.68
# t = 80.88
# t = 90.72
# t = 0.01
# t = 10.03
# t = 20.00
# t = 30.04
# t = 40.04
# t = 50.29
# t = 60.66
# t = 70.87
# t = 80.57
# t = 90.42
# t = 100.66
# t = 0.04
# t = 10.00
# t = 20.03
# t = 30.02
# t = 40.01
# t = 50.06
# t = 60.14
# t = 70.80
# t = 80.44
# t = 0.01
# t = 10.04
# t = 20.04
# t = 30.00
# t = 40.09
# t = 50.04
# t = 60.02
# t = 70.27
# t = 80.61
# t = 90.08
# t = 120.23
# t = 0.01
# t = 10.01
# t = 20.02
# t = 30.04
# t = 40.03
# t = 50.14
# t = 60.20
# t = 70.01
# t = 80.11
# t = 90.32
# t = 100.19

# %%
count_m
# Out:
# [0, 25, 18, 78, 100, 146, 133]

# %%
count_mp=[]
for graph in graph_list:
    SIGMA  = 1/5.2
    GAMMA  = 1/10
    s=2000
    R0     = 2.5
    BETA   = 1/(1/GAMMA) * R0
    model_base = SEIRSNetworkModel(G       = graph_temp, 
                          beta    = BETA, 
                          sigma   = SIGMA, 
                          gamma   = GAMMA, 
                          initE = s*0.30, initI = s*0.1)
    model_base.run(T=300)
    fig,axs = model_base.figure_basic(ylim=0.75,xlim=100)
    P = model_base.X
    cluster2 = P[1000:]
    count =0
    for i in cluster2:
        if(i==4):
            count = count+1
    count_mp.append(count)
# Out:
# t = 0.01
# t = 10.01
# t = 20.00
# t = 30.01
# t = 40.00
# t = 50.00
# t = 60.25
# t = 70.09
# t = 80.16
# t = 90.58
# t = 110.48
# t = 0.00
# t = 10.01
# t = 20.00
# t = 30.01
# t = 40.03
# t = 50.06
# t = 60.18
# t = 70.13
# t = 80.41
# t = 100.63
# t = 140.58
# t = 0.02
# t = 10.01
# t = 20.00
# t = 30.02
# t = 40.00
# t = 50.01
# t = 60.01
# t = 70.64
# t = 80.27
# t = 90.76
# t = 0.00
# t = 10.00
# t = 20.00
# t = 30.02
# t = 40.00
# t = 50.12
# t = 60.04
# t = 80.41
# t = 90.48
# t = 0.01
# t = 10.00
# t = 20.01
# t = 30.00
# t = 40.02
# t = 50.06
# t = 60.10
# t = 80.88
# t = 90.53
# t = 0.00
# t = 10.01
# t = 20.00
# t = 30.01
# t = 40.08
# t = 50.03
# t = 60.07
# t = 70.07
# t = 0.01
# t = 10.01
# t = 20.01
# t = 30.01
# t = 40.03
# t = 50.00
# t = 60.03
# t = 70.77
# t = 0.01
# t = 10.00
# t = 20.00
# t = 30.00
# t = 40.02
# t = 50.09
# t = 60.08
# t = 100.25

# %%
SIGMA  = 1/5.2
GAMMA  = 1/10
s=2000
R0     = 2.5
BETA   = 1/(1/GAMMA) * R0
model_base = SEIRSNetworkModel(G       = graph_temp, 
                          beta    = BETA, 
                          sigma   = SIGMA, 
                          gamma   = GAMMA, 
                          initE = s*0.30, initI = s*0.1)

# %%
model_base.run(T=300)
fig,axs = model_base.figure_basic(ylim=0.75,xlim=100)

line = axs.lines[1]
p = line.get_data()
p0 = p[0].compressed()
p1 = p[1].compressed()
#Maximum
m = max(p[1])
#Days Max
ind= numpy.argmax(p[1])
d = p[0][numpy.argmax(p[1])]
#Mean and St Deviation
mean  = statistics.mean(p1)
stdev =  statistics.stdev(p1)
line1 = axs.lines[2]
w = line1.get_data()
#Total Infections
tot = 1 -(w[1][w[1].shape[0]-1])
tp = 0.1*m
np = 0.9*m
#Ten Percent
tpl =[]
for i in range(len(p1)):
    x = numpy.abs(p1[i]-tp)
    if(x<0.001):
        #print(p1[i],x,p0[i])
        tpl.append(p0[i])
tplval = statistics.mean(tpl)

#Ninety Percent
nplfh =[]
nplsh = []
for i in range(ind):
    x = numpy.abs(p1[i]-np)
    if(x<0.001):
        #print(p1[i],x,p0[i])
        nplfh.append(p0[i])
for i in range(ind, len(p1)):
    x = numpy.abs(p1[i]-np)
    if(x<0.001):
        #print(p1[i],x,p0[i])
        nplsh.append(p0[i])
npl=[(statistics.mean(nplfh)),(statistics.mean(nplsh))]
# Out:
# t = 0.00
# t = 10.00
# t = 20.05
# t = 30.00
# t = 40.04
# t = 50.13
# t = 60.08
# t = 70.51
# t = 80.13
# t = 110.77

# %%
print(m,d,tot,tplval,npl, mean, stdev
     )
# Out:
# 0.264 9.488367055815466 0.8945 58.668627849796586 [5.829179119177542, 16.441780500129415] 0.19422670025188918 0.06515918712771042

# %%
P = model_base.X

# %%
cluster2 = P[1000:]
count =0
for i in cluster2:
    if(i==4):
        count = count+1

# %%
count
# Out:
# 827

# %%
graph1.number_of_edges()
# Out:
# 11215
