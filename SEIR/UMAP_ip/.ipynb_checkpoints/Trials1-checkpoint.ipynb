# %%
import time
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import matplotlib.pyplot as plt
from umap_ import *
from sklearn.datasets import make_blobs
import numpy as np
# %matplotlib inline
import scipy
import time
import networkx as nx
import collections
from collections import defaultdict
import random
import pandas as pd
import plotly.express as px
import plotly
import plotly.graph_objects as go
import umap.umap_ as umap
#import xlsxwriter
from seirsplus.models import *
from seirsplus.networks import *
import networkx

sns.set(style='darkgrid', context='poster', rc={'figure.figsize':(8,6)})
#default_seed = 16
# Out:
# /home/u58373/.local/lib/python3.7/site-packages/numba/core/cpu.py:78: UserWarning: Numba extension module 'sdc' failed to load due to 'VersionConflict((numba 0.52.0 (/home/u58373/.local/lib/python3.7/site-packages), Requirement.parse('numba<0.52,>=0.51.2')))'.
#   numba.core.entrypoints.init_all()

# %%
def ipfnA(s,c_arr, sd, n_neighbors):
    #s= no of points
    #c_arr = Array of centers
    #sd = std. dev.
    #n = n_neighbors 
#     print([s,c_arr, sd, n_neighbors])
    i=n_neighbors
    arr = [int(s/2), int(s/2)]
    data,y = make_blobs(n_samples=arr,n_features=2,random_state=16, centers=c_arr ,cluster_std=sd)
    
    r = np.random.RandomState(10)
    coo_matrix1 = umap.fuzzy_simplicial_set(data,n_neighbors,r,'euclidean')
    coo_matrix1 = np.asarray(coo_matrix1)
    sparse_matrix = coo_matrix1[0]
    #print(sparse_matrix.getnnz()

    return nx.from_scipy_sparse_matrix(sparse_matrix)

# %%
def ipfnB(s):
    G_normal    = nx.random_regular_graph(d=30, n=10000)
    #G_normal     = custom_exponential_graph(baseGraph, scale=100)
    return G_normal

# %%
def ipfnC(nodes,edges):
    G_nm = nx.gnm_random_graph(n = nodes, m = edges)
    return G_nm

# %%
def ipfnD(nodes,prob):
    G_np = nx.gnp_random_graph(n= nodes, p= prob)
    return G_np

# %%
def ipfnF(G1,s=10000):
#s = no of points
    SIGMA  = 1/5.2
    GAMMA  = 1/10
    MU_I   = 0.002

    R0     = 2.5
    BETA   = 1/(1/GAMMA) * R0
    BETA_Q = 0.5*BETA

    P      = 0.2
    Q      = 0.05
    
    model_base = SEIRSNetworkModel(G       = G1, 
                          beta    = BETA, 
                          sigma   = SIGMA, 
                          gamma   = GAMMA, 
                          initE = s*0.4, initI = s*0.1)
    
    model_base.run(T=300)
    fig,axs = model_base.figure_basic(ylim=0.5,xlim=100)
    
    line = axs.lines[1]
    p = line.get_data()
    m = max(p[1])
    d = p[0][np.argmax(p[1])]
    line1 = axs.lines[2]
    w = line1.get_data()
    tot = 1 -(w[1][w[1].shape[0]-1])
    return m,d,tot

# %%
graph_list = []
for l in range(6):
    for sdv in range(1, 7):
        graph = ipfnA(100000,[[1,1],[1,(4*l+5)]],sdv,30)
        graph_list.append(graph)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-f1f86b59f1b0> in <module>
#       2 for l in range(6):
#       3     for sdv in range(1, 7):
# ----> 4         graph = ipfnA(100000,[[1,1],[1,(4*l+5)]],sdv,30)
#       5         graph_list.append(graph)
#
# <ipython-input-2-279b0cb6d618> in ipfnA(s, c_arr, sd, n_neighbors)
#      10
#      11     r = np.random.RandomState(10)
# ---> 12     coo_matrix1 = umap.fuzzy_simplicial_set(data,n_neighbors,r,'euclidean')
#      13     coo_matrix1 = np.asarray(coo_matrix1)
#      14     sparse_matrix = coo_matrix1[0]
#
# ~/.local/lib/python3.7/site-packages/umap/umap_.py in fuzzy_simplicial_set(X, n_neighbors, random_state, metric, metric_kwds, knn_indices, knn_dists, angular, set_op_mix_ratio, local_connectivity, apply_set_operations, verbose)
#     595     if knn_indices is None or knn_dists is None:
#     596         knn_indices, knn_dists, _ = nearest_neighbors(
# --> 597             X, n_neighbors, metric, metric_kwds, angular, random_state, verbose=verbose
#     598         )
#     599
#
# ~/.local/lib/python3.7/site-packages/umap/umap_.py in nearest_neighbors(X, n_neighbors, metric, metric_kwds, angular, random_state, low_memory, use_pynndescent, verbose)
#     381                 if verbose:
#     382                     print(ts(), "Building RP forest with", str(n_trees), "trees")
# --> 383                 rp_forest = make_forest(X, n_neighbors, n_trees, rng_state, angular)
#     384                 leaf_array = rptree_leaf_array(rp_forest)
#     385                 if verbose:
#
# ~/.local/lib/python3.7/site-packages/umap/rp_tree.py in make_forest(data, n_neighbors, n_trees, rng_state, angular)
#     772         result = [
#     773             flatten_tree(make_tree(data, rng_state, leaf_size, angular), leaf_size)
# --> 774             for i in range(n_trees)
#     775         ]
#     776     except (RuntimeError, RecursionError, SystemError):
#
# ~/.local/lib/python3.7/site-packages/umap/rp_tree.py in <listcomp>(.0)
#     772         result = [
#     773             flatten_tree(make_tree(data, rng_state, leaf_size, angular), leaf_size)
# --> 774             for i in range(n_trees)
#     775         ]
#     776     except (RuntimeError, RecursionError, SystemError):
#
# ~/.local/lib/python3.7/site-packages/umap/rp_tree.py in make_tree(data, rng_state, leaf_size, angular)
#     587             return make_angular_tree(data, indices, rng_state, leaf_size)
#     588         else:
# --> 589             return make_euclidean_tree(data, indices, rng_state, leaf_size)
#     590
#     591
#
# ~/.local/lib/python3.7/site-packages/umap/rp_tree.py in make_euclidean_tree(data, indices, rng_state, leaf_size)
#     458
#     459         left_node = make_euclidean_tree(data, left_indices, rng_state, leaf_size)
# --> 460         right_node = make_euclidean_tree(data, right_indices, rng_state, leaf_size)
#     461
#     462         node = RandomProjectionTreeNode(
#
# ~/.local/lib/python3.7/site-packages/umap/rp_tree.py in make_euclidean_tree(data, indices, rng_state, leaf_size)
#     458
#     459         left_node = make_euclidean_tree(data, left_indices, rng_state, leaf_size)
# --> 460         right_node = make_euclidean_tree(data, right_indices, rng_state, leaf_size)
#     461
#     462         node = RandomProjectionTreeNode(
#
# ~/.local/lib/python3.7/site-packages/umap/rp_tree.py in make_euclidean_tree(data, indices, rng_state, leaf_size)
#     458
#     459         left_node = make_euclidean_tree(data, left_indices, rng_state, leaf_size)
# --> 460         right_node = make_euclidean_tree(data, right_indices, rng_state, leaf_size)
#     461
#     462         node = RandomProjectionTreeNode(
#
# ~/.local/lib/python3.7/site-packages/umap/rp_tree.py in make_euclidean_tree(data, indices, rng_state, leaf_size)
#     458
#     459         left_node = make_euclidean_tree(data, left_indices, rng_state, leaf_size)
# --> 460         right_node = make_euclidean_tree(data, right_indices, rng_state, leaf_size)
#     461
#     462         node = RandomProjectionTreeNode(
#
# ~/.local/lib/python3.7/site-packages/umap/rp_tree.py in make_euclidean_tree(data, indices, rng_state, leaf_size)
#     457         ) = euclidean_random_projection_split(data, indices, rng_state)
#     458
# --> 459         left_node = make_euclidean_tree(data, left_indices, rng_state, leaf_size)
#     460         right_node = make_euclidean_tree(data, right_indices, rng_state, leaf_size)
#     461
#
# ~/.local/lib/python3.7/site-packages/umap/rp_tree.py in make_euclidean_tree(data, indices, rng_state, leaf_size)
#     458
#     459         left_node = make_euclidean_tree(data, left_indices, rng_state, leaf_size)
# --> 460         right_node = make_euclidean_tree(data, right_indices, rng_state, leaf_size)
#     461
#     462         node = RandomProjectionTreeNode(
#
# ~/.local/lib/python3.7/site-packages/umap/rp_tree.py in make_euclidean_tree(data, indices, rng_state, leaf_size)
#     457         ) = euclidean_random_projection_split(data, indices, rng_state)
#     458
# --> 459         left_node = make_euclidean_tree(data, left_indices, rng_state, leaf_size)
#     460         right_node = make_euclidean_tree(data, right_indices, rng_state, leaf_size)
#     461
#
# ~/.local/lib/python3.7/site-packages/umap/rp_tree.py in make_euclidean_tree(data, indices, rng_state, leaf_size)
#     457         ) = euclidean_random_projection_split(data, indices, rng_state)
#     458
# --> 459         left_node = make_euclidean_tree(data, left_indices, rng_state, leaf_size)
#     460         right_node = make_euclidean_tree(data, right_indices, rng_state, leaf_size)
#     461
#
# ~/.local/lib/python3.7/site-packages/umap/rp_tree.py in make_euclidean_tree(data, indices, rng_state, leaf_size)
#     458
#     459         left_node = make_euclidean_tree(data, left_indices, rng_state, leaf_size)
# --> 460         right_node = make_euclidean_tree(data, right_indices, rng_state, leaf_size)
#     461
#     462         node = RandomProjectionTreeNode(
#
# ~/.local/lib/python3.7/site-packages/umap/rp_tree.py in make_euclidean_tree(data, indices, rng_state, leaf_size)
#     457         ) = euclidean_random_projection_split(data, indices, rng_state)
#     458
# --> 459         left_node = make_euclidean_tree(data, left_indices, rng_state, leaf_size)
#     460         right_node = make_euclidean_tree(data, right_indices, rng_state, leaf_size)
#     461
#
# ~/.local/lib/python3.7/site-packages/umap/rp_tree.py in make_euclidean_tree(data, indices, rng_state, leaf_size)
#     457         ) = euclidean_random_projection_split(data, indices, rng_state)
#     458
# --> 459         left_node = make_euclidean_tree(data, left_indices, rng_state, leaf_size)
#     460         right_node = make_euclidean_tree(data, right_indices, rng_state, leaf_size)
#     461
#
# ~/.local/lib/python3.7/site-packages/umap/rp_tree.py in make_euclidean_tree(data, indices, rng_state, leaf_size)
#     458
#     459         left_node = make_euclidean_tree(data, left_indices, rng_state, leaf_size)
# --> 460         right_node = make_euclidean_tree(data, right_indices, rng_state, leaf_size)
#     461
#     462         node = RandomProjectionTreeNode(
#
# ~/.local/lib/python3.7/site-packages/umap/rp_tree.py in make_euclidean_tree(data, indices, rng_state, leaf_size)
#     458
#     459         left_node = make_euclidean_tree(data, left_indices, rng_state, leaf_size)
# --> 460         right_node = make_euclidean_tree(data, right_indices, rng_state, leaf_size)
#     461
#     462         node = RandomProjectionTreeNode(
#
# ~/.local/lib/python3.7/site-packages/umap/rp_tree.py in make_euclidean_tree(data, indices, rng_state, leaf_size)
#     457         ) = euclidean_random_projection_split(data, indices, rng_state)
#     458
# --> 459         left_node = make_euclidean_tree(data, left_indices, rng_state, leaf_size)
#     460         right_node = make_euclidean_tree(data, right_indices, rng_state, leaf_size)
#     461
#
# ~/.local/lib/python3.7/site-packages/umap/rp_tree.py in make_euclidean_tree(data, indices, rng_state, leaf_size)
#     457         ) = euclidean_random_projection_split(data, indices, rng_state)
#     458
# --> 459         left_node = make_euclidean_tree(data, left_indices, rng_state, leaf_size)
#     460         right_node = make_euclidean_tree(data, right_indices, rng_state, leaf_size)
#     461
#
# ~/.local/lib/python3.7/site-packages/umap/rp_tree.py in make_euclidean_tree(data, indices, rng_state, leaf_size)
#     457         ) = euclidean_random_projection_split(data, indices, rng_state)
#     458
# --> 459         left_node = make_euclidean_tree(data, left_indices, rng_state, leaf_size)
#     460         right_node = make_euclidean_tree(data, right_indices, rng_state, leaf_size)
#     461
#
# ~/.local/lib/python3.7/site-packages/umap/rp_tree.py in make_euclidean_tree(data, indices, rng_state, leaf_size)
#     458
#     459         left_node = make_euclidean_tree(data, left_indices, rng_state, leaf_size)
# --> 460         right_node = make_euclidean_tree(data, right_indices, rng_state, leaf_size)
#     461
#     462         node = RandomProjectionTreeNode(
#
# ~/.local/lib/python3.7/site-packages/umap/rp_tree.py in make_euclidean_tree(data, indices, rng_state, leaf_size)
#     461
#     462         node = RandomProjectionTreeNode(
# --> 463             None, False, hyperplane, offset, left_node, right_node
#     464         )
#     465     else:
#
# <string> in __new__(_cls, indices, is_leaf, hyperplane, offset, left_child, right_child)
#
# KeyboardInterrupt:

# %%
graph_list = []
graph = ipfnA(10000,[[1,1],[1,11]],3,30)
graph_ba = ipfnB(10000)
graph_nm = ipfnC(10000, 15000)
graph_np = ipfnD(10000, 0.5)
graph_list.append(graph)
graph_list.append(graph_ba)
graph_list.append(graph_nm)
graph_list.append(graph_np)
# Out:
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
for i in graph_list:
    nx.draw(i)
# Out:
# /home/u58373/.local/lib/python3.7/site-packages/networkx/drawing/layout.py:638: RuntimeWarning: divide by zero encountered in true_divide
#   delta * (k * k / distance ** 2 - Ai * distance / k)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-c42be032b9aa> in <module>
#       1 for i in graph_list:
# ----> 2     nx.draw(i)
#
# ~/.local/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py in draw(G, pos, ax, **kwds)
#     121         kwds["with_labels"] = "labels" in kwds
#     122
# --> 123     draw_networkx(G, pos=pos, ax=ax, **kwds)
#     124     ax.set_axis_off()
#     125     plt.draw_if_interactive()
#
# ~/.local/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     331
#     332     if pos is None:
# --> 333         pos = nx.drawing.spring_layout(G)  # default to spring layout
#     334
#     335     draw_networkx_nodes(G, pos, **node_kwds)
#
# <decorator-gen-852> in fruchterman_reingold_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#
# ~/.local/lib/python3.7/site-packages/networkx/utils/decorators.py in _random_state(func, *args, **kwargs)
#     406         new_args = list(args)
#     407         new_args[random_state_index] = random_state
# --> 408         return func(*new_args, **kwargs)
#     409
#     410     return _random_state
#
# ~/.local/lib/python3.7/site-packages/networkx/drawing/layout.py in fruchterman_reingold_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#     490             k = dom_size / np.sqrt(nnodes)
#     491         pos = _sparse_fruchterman_reingold(
# --> 492             A, k, pos_arr, fixed, iterations, threshold, dim, seed
#     493         )
#     494     except ValueError:
#
# <decorator-gen-856> in _sparse_fruchterman_reingold(A, k, pos, fixed, iterations, threshold, dim, seed)
#
# ~/.local/lib/python3.7/site-packages/networkx/utils/decorators.py in _random_state(func, *args, **kwargs)
#     406         new_args = list(args)
#     407         new_args[random_state_index] = random_state
# --> 408         return func(*new_args, **kwargs)
#     409
#     410     return _random_state
#
# ~/.local/lib/python3.7/site-packages/networkx/drawing/layout.py in _sparse_fruchterman_reingold(A, k, pos, fixed, iterations, threshold, dim, seed)
#     637             displacement[:, i] += (
#     638                 delta * (k * k / distance ** 2 - Ai * distance / k)
# --> 639             ).sum(axis=1)
#     640         # update positions
#     641         length = np.sqrt((displacement ** 2).sum(axis=0))
#
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.7/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      45 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      46          initial=_NoValue, where=True):
# ---> 47     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      48
#      49 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# KeyboardInterrupt:

# %%
M = []
D = []
T= []
for i in graph_list:
    for _ in range(1):
        peak,days,tot = ipfnF(i)
        M.append(peak)
        D.append(days)
        T.append(tot)
# Out:
# t = 0.00
# t = 10.00
# t = 20.00
# t = 30.00
# t = 40.03
# t = 50.04
# t = 60.05
# t = 70.13
# t = 80.24
# t = 100.31
# t = 110.15
# t = 0.00
# t = 10.00
# t = 20.00
# t = 30.00
# t = 40.01
# t = 50.01
# t = 60.00
# t = 70.03
# t = 80.15
# t = 90.10
# t = 0.00
# t = 10.00
# t = 20.01
# t = 30.00
# t = 40.01
# t = 50.03
# t = 60.05
# t = 70.06
# t = 80.10
# t = 110.70
# t = 0.00
# t = 10.00
# t = 20.00
# t = 30.00
# t = 40.02
# t = 50.02
# t = 60.09
# t = 70.04
# t = 80.20
# t = 90.69
# t = 100.19
# t = 110.66
# t = 130.31

# %%
print(M)
print(D)
print(T)
# Out:
# [0.2775, 0.3172, 0.306, 0.3167]
# [7.351067645178622, 10.741874414692232, 8.41464026800104, 11.038833723078143]
# [0.7959, 0.9512, 0.8499, 0.9601999999999999]

# %%
s=10000
SIGMA  = 1/5.2
GAMMA  = 1/10
MU_I   = 0.002

R0     = 2.5
BETA   = 1/(1/GAMMA) * R0
BETA_Q = 0.5*BETA

P      = 0.2
Q      = 0.05
    
model_base = SEIRSNetworkModel(G       = graph, 
                          beta    = BETA, 
                          sigma   = SIGMA, 
                          gamma   = GAMMA, 
                          initE = s*0.4, initI = s*0.1)
    
model_base.run(T=300)
fig,axs = model_base.figure_basic(ylim=0.5,xlim=100)
    
line = axs.lines[1]
p = line.get_data()
m = max(p[1])
d = p[0][np.argmax(p[1])]
# Out:
# t = 0.00
# t = 10.00
# t = 20.00
# t = 30.01
# t = 40.01
# t = 50.03
# t = 60.04
# t = 70.00
# t = 80.36
# t = 90.19
# t = 100.04
# t = 110.29
# t = 120.57
# t = 150.87

# %%
line = axs.lines[2]
p = line.get_data()
p[1][p[1].shape[0]-1]
# Out:
# 0.2129
